# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.cloud import bigquery
import google.generativeai as genai
from dotenv import load_dotenv

print("All packages imported successfully!")
# Out:
# All packages imported successfully!

# %%
from config import client

print(client.project)
# Out:
# bizanalytics-project

# %%
from config import client

def run_query(sql_query):
    query_job = client.query(sql_query)
    df = query_job.to_dataframe()
    return df

# %%
from bigquery_helper import run_query

query = """
SELECT *
FROM ecommerce_raw.orders
LIMIT 5
"""

df = run_query(query)

df
# Out:
# C:\Users\asus\New folder\Lib\site-packages\google\cloud\bigquery\table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                            order_id                       customer_id  \
# 0  a2e4c44360b4a57bdff22f3a4630c173  8886130db0ea6e9e70ba0b03d7c0d286
# 1  132f1e724165a07f6362532bfb97486e  b2191912d8ad6eac2e4dc3b6e1459515
# 2  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 3  e5215415bb6f76fe3b7cb68103a0d1c0  b6f6cbfc126f1ae6723fe2f9b3751208
# 4  71303d7e93b399f5bcd537d124c0bcfa  b106b360fe2ef8849fbbd056f777b4d5
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0     approved      2017-02-06 20:18:17  2017-02-06 20:30:19
# 1     approved      2017-04-25 01:25:34  2017-04-30 20:32:41
# 2     canceled      2016-09-13 15:24:19  2016-10-07 13:16:46
# 3     canceled      2016-10-22 08:25:27                 None
# 4     canceled      2016-10-02 22:07:52  2016-10-06 15:50:56
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                         None                          None
# 1                         None                          None
# 2                         None                          None
# 3                         None                          None
# 4                         None                          None
#
#   order_estimated_delivery_date
# 0           2017-03-01 00:00:00
# 1           2017-05-22 00:00:00
# 2           2016-09-30 00:00:00
# 3           2016-10-24 00:00:00
# 4           2016-10-25 00:00:00
